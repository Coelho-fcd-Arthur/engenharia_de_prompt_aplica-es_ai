# %% [markdown]
# <a href="https://colab.research.google.com/github/Coelho-fcd-Arthur/engenharia_de_prompt_aplica-es_ai/blob/main/Aula081.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
  print("Escolha o operador:")
  print("+ para Soma")
  print("- para Subtração")
  print("* para Multiplicação")
  print("/ para Divisão")

  operacao = (input("digite a forma de operação: "))
  n1 = int(input("digite o primeiro numero: "))
  n2 = int(input("digite o segundo numero: "))

  if operacao == "+":
    resultado = n1 + n2
    print(f"O resultado de {n1} + {n2} = {resultado}")
  elif operacao == "-":
    resultado = n1 - n2
    print(f"O resultado de {n1} - {n2} = {resultado}")
  elif operacao == "*":
    resultado = n1 * n2
    print(f"O resultado de {n1} * {n2} = {resultado}")
  elif operacao == "/":
    resultado = n1 / n2
    print(f"O resultado de {n1} / {n2} = {resultado}")
  else:
    print("voce encerrou o programa")
    break
# Out:
# Escolha o operador:
# + para Soma
# - para Subtração
# * para Multiplicação
# / para Divisão
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4174/3876920220.py", line 8, in <cell line: 0>
#     operacao = (input("digite a forma de operação: "))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 1177, in raw_input
#     return self._input_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 1219, in _input_request
#     raise KeyboardInterrupt("Interrupted by user") from None
# KeyboardInterrupt: Interrupted by user
#
# ...
